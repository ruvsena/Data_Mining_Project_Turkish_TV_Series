# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
data=pd.read_csv("dizi_verisi_95_23.xlsx - Sayfa1 (2).csv")

# %%
data.head()
# Out:
#       Dizi Adı English   Referans  Başlama Yılı  Bitiş Yılı  \
# 0    Bir Demet Tiyatro  1995–2007          1995        2007
# 1        Reyting Hamdi  1995–2007          1995        2007
# 2          Çiçek taksi  1995–2003          1995        2003
# 3             Bizim Ev       1995          1995        1998
# 4  Boşgezen ve kalfası       1995          1995        1995
#
#   Referans-Ortalama Süre  Ortalama Süre   Tür-1    Tür-2 Tür-3  Bölüm Sayısı  \
# 0                   0,75           45.0  Comedy   Family               156.0
# 1                   0,60           40.0  Comedy                        367.0
# 2                   1,00           60.0  Comedy    Drama               367.0
# 3                   1,00           60.0   Drama                        101.0
# 4                   0,75           45.0  Comedy  Fantasy                 8.0
#
#    ...        Senarist-3    Senarist-4         Senarist-5        Yapımcı-1  \
# 0  ...                                                      Necati Akpinar
# 1  ...  Murat Boyacioglu  Mesut Ceylan  Nur Özlem Elginöz      Hamdi Alkan
# 2  ...     Yilmaz Okumus    Atay Sözer    Hayal Tacirleri  Türker Inanoglu
# 3  ...               NaN           NaN                NaN              NaN
# 4  ...                                                          Ömer Sahin
#
#            Yapımcı-2 Yapımcı-3           Müzisyen-1      Müzisyen-2  \
# 0                          NaN           Grup Çagri
# 1  Süleyman Nebioglu       NaN       Engin Özyilmaz  Erdem Özyilmaz
# 2                          NaN  Murat Pinar Ozdemir    Özkan Turgay
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#   Müzisyen-3 Başarı Metrigi
# 0                         4
# 1                         4
# 2                         4
# 3                         3
# 4                         1
#
# [5 rows x 38 columns]

# %%
data.tail()
# Out:
#               Dizi Adı English Referans  Başlama Yılı  Bitiş Yılı  \
# 701               Kirli Sepeti    2023–          2023        2023
# 702                       Ömer    2023–          2023        2023
# 703                   Magarsus    2023–          2023        2023
# 704  Tozkoparan Iskender Gölge    2023–          2023        2023
# 705               Ruhun Duymaz     2023          2023        2023
#
#     Referans-Ortalama Süre  Ortalama Süre   Tür-1  Tür-2 Tür-3  Bölüm Sayısı  \
# 701                   1,00           60.0  Comedy  Drama                11.0
# 702                   2,00          120.0   Drama                       37.0
# 703                   1,00           60.0   Drama                        9.0
# 704                   1,00           60.0  Sci-Fi                       11.0
# 705                   2,00          120.0  Comedy  Drama                 9.0
#
#      ...          Senarist-3       Senarist-4           Senarist-5  \
# 701  ...        Sertaç Sayin  Nermin Yildirim
# 702  ...  Yehonatan Indursky  Vural Yasaroglu  Sedef Bayburtluoglu
# 703  ...
# 704  ...                                  NaN
# 705  ...          Cem Görgeç       Ayse Kutlu           Ayse Kutlu
#
#           Yapımcı-1         Yapımcı-2           Yapımcı-3         Müzisyen-1  \
# 701     Fatih Aksoy      Merve Girgin  Direnç Aksoy Sidar      Aytaç Özgümüs
# 702  Onur Güvenatam  Oguzhan Sakaoglu           Aysil Tay         Alp Yenier
# 703  Serkan Cakarer        Yamac Okur      Baris Yildirim      Toygar Isikli
# 704     Ferhat Ayan                                   NaN  Ömer Faruk Berker
# 705      Saner Ayar      Omer Lekesiz                 NaN       Recby Saatçi
#
#           Müzisyen-2    Müzisyen-3 Başarı Metrigi
# 701   Sertaç Özgümüs                            1
# 702                                             2
# 703                                             2
# 704  Burcu Memisoglu  Serkan Semiz              3
# 705     Ercan Saatçi   Ilker Yeter              1
#
# [5 rows x 38 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 706 entries, 0 to 705
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Dizi Adı English        706 non-null    object
#  1   Referans                706 non-null    object
#  2   Başlama Yılı            706 non-null    int64
#  3   Bitiş Yılı              706 non-null    int64
#  4   Referans-Ortalama Süre  706 non-null    object
#  5   Ortalama Süre           705 non-null    float64
#  6   Tür-1                   706 non-null    object
#  7   Tür-2                   706 non-null    object
#  8   Tür-3                   702 non-null    object
#  9   Bölüm Sayısı            706 non-null    float64
#  10  Sezon Sayısı            706 non-null    int64
#  11  Oyuncu-1                706 non-null    object
#  12  Oyuncu-2                706 non-null    object
#  13  Oyuncu-3                706 non-null    object
#  14  Oyuncu-4                706 non-null    object
#  15  Oyuncu-5                706 non-null    object
#  16  Oyuncu-6                706 non-null    object
#  17  Oyuncu-7                706 non-null    object
#  18  Oyuncu-8                706 non-null    object
#  19  Oyuncu-9                706 non-null    object
#  20  Oyuncu-10               706 non-null    object
#  21  Yapımcı Şirket          706 non-null    object
#  22  Yayıncı Kuruluşlar-1    706 non-null    object
#  23  Yayıncı Kuruluşlar-2    706 non-null    object
#  24  İhraç Edildi Mi?        705 non-null    object
#  25  Yönetmen                697 non-null    object
#  26  Senarist-1              706 non-null    object
#  27  Senarist-2              676 non-null    object
#  28  Senarist-3              699 non-null    object
#  29  Senarist-4              677 non-null    object
#  30  Senarist-5              697 non-null    object
#  31  Yapımcı-1               679 non-null    object
#  32  Yapımcı-2               706 non-null    object
#  33  Yapımcı-3               269 non-null    object
#  34  Müzisyen-1              660 non-null    object
#  35  Müzisyen-2              706 non-null    object
#  36  Müzisyen-3              706 non-null    object
#  37  Başarı Metrigi          706 non-null    int64
# dtypes: float64(2), int64(4), object(32)
# memory usage: 209.7+ KB

# %%
data.shape
# Out:
# (706, 38)

# %%
data=data.drop(['İhraç Edildi Mi?'],axis=1)

# %%
data.head()
# Out:
#       Dizi Adı English   Referans  Başlama Yılı  Bitiş Yılı  \
# 0    Bir Demet Tiyatro  1995–2007          1995        2007
# 1        Reyting Hamdi  1995–2007          1995        2007
# 2          Çiçek taksi  1995–2003          1995        2003
# 3             Bizim Ev       1995          1995        1998
# 4  Boşgezen ve kalfası       1995          1995        1995
#
#   Referans-Ortalama Süre  Ortalama Süre   Tür-1    Tür-2 Tür-3  Bölüm Sayısı  \
# 0                   0,75           45.0  Comedy   Family               156.0
# 1                   0,60           40.0  Comedy                        367.0
# 2                   1,00           60.0  Comedy    Drama               367.0
# 3                   1,00           60.0   Drama                        101.0
# 4                   0,75           45.0  Comedy  Fantasy                 8.0
#
#    ...        Senarist-3    Senarist-4         Senarist-5        Yapımcı-1  \
# 0  ...                                                      Necati Akpinar
# 1  ...  Murat Boyacioglu  Mesut Ceylan  Nur Özlem Elginöz      Hamdi Alkan
# 2  ...     Yilmaz Okumus    Atay Sözer    Hayal Tacirleri  Türker Inanoglu
# 3  ...               NaN           NaN                NaN              NaN
# 4  ...                                                          Ömer Sahin
#
#            Yapımcı-2 Yapımcı-3           Müzisyen-1      Müzisyen-2  \
# 0                          NaN           Grup Çagri
# 1  Süleyman Nebioglu       NaN       Engin Özyilmaz  Erdem Özyilmaz
# 2                          NaN  Murat Pinar Ozdemir    Özkan Turgay
# 3                          NaN                  NaN
# 4                          NaN                  NaN
#
#   Müzisyen-3 Başarı Metrigi
# 0                         4
# 1                         4
# 2                         4
# 3                         3
# 4                         1
#
# [5 rows x 37 columns]

# %%
valuecont=data['Başarı Metrigi'].value_counts()

# %%
data.isnull().sum()
# Out:
# Dizi Adı English            0
# Referans                    0
# Başlama Yılı                0
# Bitiş Yılı                  0
# Referans-Ortalama Süre      0
# Ortalama Süre               1
# Tür-1                       0
# Tür-2                       0
# Tür-3                       4
# Bölüm Sayısı                0
# Sezon Sayısı                0
# Oyuncu-1                    0
# Oyuncu-2                    0
# Oyuncu-3                    0
# Oyuncu-4                    0
# Oyuncu-5                    0
# Oyuncu-6                    0
# Oyuncu-7                    0
# Oyuncu-8                    0
# Oyuncu-9                    0
# Oyuncu-10                   0
# Yapımcı Şirket              0
# Yayıncı Kuruluşlar-1        0
# Yayıncı Kuruluşlar-2        0
# Yönetmen                    9
# Senarist-1                  0
# Senarist-2                 30
# Senarist-3                  7
# Senarist-4                 29
# Senarist-5                  9
# Yapımcı-1                  27
# Yapımcı-2                   0
# Yapımcı-3                 437
# Müzisyen-1                 46
# Müzisyen-2                  0
# Müzisyen-3                  0
# Başarı Metrigi              0
# dtype: int64

# %%
mean_value = data['Ortalama Süre'].mean()

data['Ortalama Süre'] = data['Ortalama Süre'].fillna(mean_value)

# %%
data.isnull().sum()
# Out:
# Dizi Adı English            0
# Referans                    0
# Başlama Yılı                0
# Bitiş Yılı                  0
# Referans-Ortalama Süre      0
# Ortalama Süre               0
# Tür-1                       0
# Tür-2                       0
# Tür-3                       4
# Bölüm Sayısı                0
# Sezon Sayısı                0
# Oyuncu-1                    0
# Oyuncu-2                    0
# Oyuncu-3                    0
# Oyuncu-4                    0
# Oyuncu-5                    0
# Oyuncu-6                    0
# Oyuncu-7                    0
# Oyuncu-8                    0
# Oyuncu-9                    0
# Oyuncu-10                   0
# Yapımcı Şirket              0
# Yayıncı Kuruluşlar-1        0
# Yayıncı Kuruluşlar-2        0
# Yönetmen                    9
# Senarist-1                  0
# Senarist-2                 30
# Senarist-3                  7
# Senarist-4                 29
# Senarist-5                  9
# Yapımcı-1                  27
# Yapımcı-2                   0
# Yapımcı-3                 437
# Müzisyen-1                 46
# Müzisyen-2                  0
# Müzisyen-3                  0
# Başarı Metrigi              0
# dtype: int64

# %%
valuecont.plot(kind="bar", xlabel="Category", ylabel="Count", legend=False)
plt.title("Value Counts of Category")
plt.show()

# %%
data['Ortalama Süre']=data['Ortalama Süre'].astype(int)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['Tür-1'] = label_encoder.fit_transform(data['Tür-1'])

# %%
class_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(class_mapping)
# Out:
# {' Drama': 0, 'Action': 1, 'Adventure': 2, 'Animation': 3, 'Biography': 4, 'Comedy': 5, 'Crime': 6, 'Drama': 7, 'Family': 8, 'Fantasy': 9, 'History': 10, 'Income': 11, 'Musical': 12, 'Romance': 13, 'Sci-Fi': 14, 'Short': 15}

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['Yapımcı Şirket'] = label_encoder.fit_transform(data['Yapımcı Şirket'])

# %%
class_mapping1 = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(class_mapping1)
# Out:
# {' ': 0, '1441 Productions': 1, '3 Nokta Film': 2, 'AC Film': 3, 'AFS Film': 4, 'ANS': 5, 'ANS Production': 6, 'ANS Productions': 7, 'ARC Film': 8, 'ATV': 9, 'Acar Entertainment': 10, 'Acayip Medya': 11, 'Acun Medya': 12, 'Adam Film': 13, 'Akli Film': 14, 'Altinkesit': 15, 'Altioklar Film': 16, 'Arti Film': 17, 'Artistanbul': 18, 'At Yapim': 19, 'Avrupa Film': 20, 'Avsar Film': 21, 'Avsar Yapim': 22, 'Ay Yapim': 23, 'AyNA Yapim': 24, 'BKM': 25, 'BSK Yapim': 26, 'Bando TV': 27, 'Barakuda Film Production': 28, 'Base Productions': 29, 'Base Yapim': 30, 'Baytimur': 31, 'Besiktas Kültür Merkezi (BKM)': 32, 'Bi Yapim': 33, 'Birlesik Heyecanlar': 34, 'Birsel Film': 35, 'BluTV': 36, 'Bosphorus Filmmakers': 37, 'Bosphorus Films': 38, 'Boyut Film': 39, 'Bozdag Film': 40, 'CMYLMZ Fikirsanat': 41, 'CaglarArts Entertainment': 42, 'Calinos Entertainment': 43, 'Cameo Yapim': 44, 'Carthage Plus TV': 45, 'Columbia TriStar International Television': 46, 'D Production': 47, 'D Productions': 48, 'Dada Film': 49, 'Detay Film': 50, 'Devekusu': 51, 'Dogru Isler Yapim': 52, 'Doku Film': 53, 'Dramax': 54, 'Duka Film': 55, 'Düs Gezginleri': 56, 'Düsyeri': 57, 'ES Film': 58, 'Eflatun Film': 59, 'Endemol Shine Turkey': 60, 'Erler Film': 61, 'Eryapim': 62, 'Es Yapim': 63, 'Eylül Tv': 64, 'FARO Company': 65, 'FF Yapim': 66, 'FM Yapim': 67, 'Fabrika Yapim': 68, 'Fida Film': 69, 'Filmevi Yapim': 70, 'Focus Film Production': 71, 'Focus Films': 72, 'Fora Film': 73, 'Fotoroman Film': 74, 'Fox TV': 75, 'Games Medya': 76, 'Gergedan Film': 77, 'Global Produksiyon': 78, 'Gold Film': 79, 'Grafi2000 Production': 80, 'Green Yapim': 81, 'Güzel Adamlar': 82, 'Harem Produksiyon': 83, 'IVI': 84, 'Idea Film Creatives': 85, 'Ilke Film': 86, 'Inter Medya': 87,
dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(class_mapping2)
# Out:
# {' ': 0, '1+1': 1, '1+1 Production': 2, '8MM production': 3, 'ANT1': 4, 'ATV': 5, 'AXN White': 6, 'Aksoy Film': 7, 'Ali Sabuncugil Casting Agency': 8, 'Antena 3': 9, 'Atrium Productions': 10, 'Avanti Ciné Vidéo Inc.': 11, 'Avsar Film': 12, 'Ay Yapim': 13, 'BKM': 14, 'Beta Film': 15, 'Beyaz TV': 16, 'BluTV': 17, 'Carthage Plus TV': 18, 'Columbia TriStar Domestic Television': 19, 'Columbia TriStar Television': 20, 'Disney Channel': 21, 'Disney+': 22, 'Divinity': 23, 'Dramax': 24, 'Eccho Rights': 25, 'Eflatun Film': 26, 'El Trece': 27, 'Endemol Shine Turkey': 28, 'Evrensel Filimcilik': 29, 'Express Entertainment': 30, 'Exxen': 31, 'FOXplay': 32, 'Flash TV': 33, 'Fora Film': 34, 'Fourwalled Films': 35, 'Fox Network': 36, 'Fox TV': 37, 'Gain': 38, 'Global Agency': 39, 'Gold Film': 40, 'Hannibal TV': 41, 'IMDb Answers: Help fill gaps in our data': 42, 'Imaj': 43, 'Kanal 1': 44, 'Kanal 7': 45, 'Kanal D': 46, 'Klan TV': 47, 'Medyapim': 48, 'Monte Carlo TV': 49, 'Monte Carlo Televisión - Canal 4': 50, 'Nessma TV': 51, 'Netflix': 52, 'Pana Film': 53, 'Perve TV': 54, 'Plato Film Production': 55, 'Puhu TV': 56, 'RTL Klub Televízió': 57, 'STAR TV': 58, 'STM': 59, 'STV': 60, 'Samanyolu TV (STV)': 61, 'Show TV': 62, 'Sony Pictures Television': 63, 'Star': 64, 'Star TV': 65, 'TGRT': 66, 'TOD': 67, 'TRT 1': 68, 'TRT 1 Türk Sinemasi': 69, 'TV8': 70, 'Tabii': 71, 'Turkish Radio & Television (TRT)': 72, 'Victory': 73, 'Videomite': 74, 'Vizyon': 75}

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['Senarist-1'] = label_encoder.fit_transform(data['Senarist-1'])

# %%
class_mapping3 = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
print(class_mapping3)
# Out:
# {' ': 0, 'Abdullah Akin': 1, 'Abdülhamit Avsar': 2, 'Adem Biyik': 3, 'Ahmet Birsen': 4, 'Ahmet Ruhan Arca': 5, 'Ahmet Saatçioglu': 6, 'Ahmet Yurdakul': 7, 'Aksel Bonfil': 8, 'Alev Alatli': 9, 'Ali Aydin': 10, 'Ali Can Yaras': 11, 'Ali Demirel': 12, 'Ali Dogancay': 13, 'Ali Ercivan': 14, 'Ali Otyam': 15, 'Ali Ulvi Hünkar': 16, 'Alper Alpözgen': 17, 'Alper Caglar': 18, 'Alper Erze': 19, 'Alphan Dikmen': 20, 'Armagan Gülsahin': 21, 'Arzu Birol': 22, 'Aslan Avigdor': 23, 'Asli Ayhan': 24, 'Asli Zengin': 25, 'Asli Zeynep Peker Bozdag': 26, 'Atil Inaç': 27, 'Atilla Atalay': 28, 'Aybars Bora Kahyaoglu': 29, 'Ayberk Cinar': 30, 'Ayhan Sonyürek': 31, 'Aylin Aliveren': 32, 'Ayse Kulin': 33, 'Ayse Kutlu': 34, 'Ayse Sule Bilgiç': 35, 'Ayse Teber': 36, 'A
naz Yos Saracoglu': 140, 'Gurkan Tanyas': 141, 'Gökhan Atasoy': 142, 'Gökhan Horzum': 143, 'Göktug Kara': 144, 'Gül Abus Semerci': 145, 'Gül Gürsoy': 146, 'Gül Oguz': 147, 'Gülay Batur': 148, 'Güliz Kucur': 149, 'Gülizar Irmak': 150, 'Gülse Birsel': 151, 'Gülseren Aydin': 152, 'Gülseren Budayicioglu': 153, 'Hakan Biçakçi': 154, 'Hakan Bonomo': 155, 'Hakan Gunday': 156, 'Hakan Haksun': 157, 'Hakan Mumcuoglu': 158, 'Haluk Can Dizdaroglu': 159, 'Haluk Özenç': 160, 'Hande Altayli': 161, 'Hasan Burak Kayaci': 162, 'Hasan Erimez': 163, 'Hasan Kaçan': 164, 'Hayal Tacirleri': 165, 'Hayriye Ersöz': 166, 'Hazar Kozice': 167, 'Hazel Sevim Unsal': 168, 'Hikmet Tombulca': 169, 'Hürer Ebeoglu': 170, 'Hüseyin Karakas': 171, 'Hüseyin Kuzu': 172, 'Hüsnü Özçetin': 173, 'Ibrahim Altun': 174, 'Ibrahim Bal': 175, 'Ibrahim Ethem Arslan': 176, 'Iclal Aydin': 177, 'Ihsan Aydin': 178, 'Ilhami Algör': 179, 'Ilker Arslan': 180, 'Ilker Baris': 181, 'Inan Güngören': 182, 'Inci Hekimoglu': 183, 'Inci Özlem Hekimoglu': 184, 'Isa Yildiz': 185, 'Isil Sonmez': 186, 'Ismail Içen': 187, 'Jacek Dukaj': 188, 'Kaktüs Yazi G ...

# %%
np.random.seed(42)
corr_data=pd.DataFrame({'Başlama Yılı':np.random.rand(5),'Senarist-1':np.random.rand(5),'Başarı Metrigi':np.random.rand(5),'Yayıncı Kuruluşlar-1':np.random.rand(5),'Ortalama Süre':np.random.rand(5),'Yapımcı Şirket':np.random.rand(5),'Tür-1':np.random.rand(5)})
corr_matrix3=data.corr()['Başarı Metrigi']
# Out:
# <ipython-input-94-5605ea585e39>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix3=data.corr()['Başarı Metrigi']

# %%
print(corr_data)
# Out:
#    Başlama Yılı  Senarist-1  Başarı Metrigi  Yayıncı Kuruluşlar-1  \
# 0      0.374540    0.155995        0.020584              0.183405
# 1      0.950714    0.058084        0.969910              0.304242
# 2      0.731994    0.866176        0.832443              0.524756
# 3      0.598658    0.601115        0.212339              0.431945
# 4      0.156019    0.708073        0.181825              0.291229
#
#    Ortalama Süre  Yapımcı Şirket     Tür-1     Tür-2
# 0       0.611853        0.785176  0.607545  0.808397
# 1       0.139494        0.199674  0.170524  0.304614
# 2       0.292145        0.514234  0.065052  0.097672
# 3       0.366362        0.592415  0.948886  0.684233
# 4       0.456070        0.046450  0.965632  0.440152

# %%
plt.figure(figsize=(6,6))
sns.heatmap(corr_data.corr(),annot=True,fmt=".1f",linewidths=.7)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
droplist=['Referans','Referans-Ortalama Süre','Tür-2','Tür-3','Oyuncu-1','Oyuncu-2','Oyuncu-3','Oyuncu-4','Oyuncu-5','Oyuncu-6','Oyuncu-7','Oyuncu-8','Oyuncu-9','Oyuncu-10','Yapımcı Şirket','Yayıncı Kuruluşlar-1','Yayıncı Kuruluşlar-2','Yönetmen','Senarist-1','Senarist-2','Senarist-3','Senarist-4','Senarist-5','Yapımcı-1','Yapımcı-2','Yapımcı-3','Müzisyen-1','Müzisyen-2']

# %%
data1=data.drop(['Sezon Sayısı','Bölüm Sayısı','Müzisyen-3'], axis=1)
data1.head()
# Out:
#    Başlama Yılı  Ortalama Süre  Tür-1  Yapımcı Şirket  Yayıncı Kuruluşlar-1  \
# 0          1995             45      5              25                    74
# 1          1995             40      5              91                     0
# 2          1995             60      5              61                     0
# 3          1995             60      7              15                     0
# 4          1995             45      5              93                     0
#
#    Senarist-1  Başarı Metrigi
# 0         348               4
# 1         221               4
# 2         287               4
# 3           0               3
# 4         127               1

# %%
x=data1[['Başlama Yılı','Yapımcı Şirket','Ortalama Süre','Senarist-1','Yayıncı Kuruluşlar-1','Tür-1']].values
y=data1[['Başarı Metrigi']].values
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression(random_state=42,solver="liblinear",C=1.6,penalty="l1")
lr_model.fit(X_train,y_train)
y_head_lr=lr_model.predict(X_test)
lr_score=lr_model.score(X_test,y_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print(lr_score)
# Out:
# 0.5422535211267606

# %%
cm_lr = confusion_matrix(y_test,y_head_lr)
print(cm_lr)
# Out:
# [[77  0  0  0  0]
#  [30  0  0  0  0]
#  [28  0  0  0  0]
#  [ 5  0  0  0  0]
#  [ 2  0  0  0  0]]

# %%
from sklearn.neighbors import KNeighborsClassifier
knn_model = KNeighborsClassifier(n_neighbors=4,weights="distance")

knn_model.fit(X_train,y_train)

y_head_knn = knn_model.predict(X_test)

knn_score = knn_model.score(X_test,y_test)
print(knn_score)
# Out:
# 0.45774647887323944
# /usr/local/lib/python3.10/dist-packages/sklearn/neighbors/_classification.py:215: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
cm_knn = confusion_matrix(y_test,y_head_knn)
print(cm_knn)
# Out:
# [[52 18  5  0  2]
#  [18  9  3  0  0]
#  [15 10  3  0  0]
#  [ 3  0  1  1  0]
#  [ 1  1  0  0  0]]

# %%
plt.figure(figsize=(24,12))

plt.suptitle("Confusion Matrixes",fontsize=24)

plt.subplot(2,3,1)
plt.title("Logistic Regression Confusion Matrix")
sns.heatmap(cm_lr,cbar=False,annot=True,cmap="CMRmap_r",fmt="d")

plt.subplot(2,3,3)
plt.title("K Nearest Neighbors Confusion Matrix")
sns.heatmap(cm_knn,cbar=False,annot=True,cmap="CMRmap_r",fmt="d")

plt.show()

# %%
new_data=pd.DataFrame({'Başlama Yılı':[2018],'Yapımcı Şirket':[109],'Ortalama Süre':[120],'Tür-1':[0],'Senarist-1':[41],'Yayıncı Kuruluş':[47]})
predictions = knn_model.predict(new_data)
print(predictions)
# Out:
# [1]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but KNeighborsClassifier was fitted without feature names
#   warnings.warn(

# %%
new_data1=pd.DataFrame({'Başlama Yılı':[2022,2021],'Yapımcı Şirket':[23,161],'Ortalama Süre':[45,120],'Tür-1':[0,0],'Senarist-1':[217,329],'Yayıncı Kuruluş':[121,9]})
predictions = lr_model.predict(new_data1)
print(predictions)
# Out:
# [1 2]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
